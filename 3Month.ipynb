# %% [markdown]
# ## ***Scenerio:***
#
#
# Being a junior data analyst working in the marketing analyst team at Cyclistic, a bike-share company in Chicago. The director
# of marketing believes the company’s future success depends on maximizing the number of annual memberships. Therefore,
# your team wants to understand how casual riders and annual members use Cyclistic bikes differently. From these insights,
# your team will design a new marketing strategy to convert casual riders into annual members. But first, Cyclistic executives
# must approve your recommendations, so they must be backed up with compelling data insights and professional data
# visualizations

# %% [markdown]
# ### ***Business task as of scenario given***:
#
# ---
#
#
#
#
# *   How the casual and annual riders use Cyclist differently
# *   How to convert the casual into member(Annual)

# %% [markdown]
# ***Here using the each month data to obtain the analysis individually. We can do this to every month but im using the last 3 month data of the year which is being provided to by the company for analysis***

# %% [markdown]
# ### ***Data Cleaning:***
#
# ---
# Before we clean the data, we will store all the 12 months csv file in a folder named "Data"
# Then, here i have used excel to clean the data for each file before analyzing the whole 12 months data using python
#
# **Steps to clean the data in excel:**
#
#
# 1.   Remove Duplicate
# 2.   Fix structural Error
# 3.   Filter unwanted outliers
# 4.   Handle missing data
# 5.   Validate

# %% [markdown]
# -After cleaning the data i took and overview of the data to get an idea what are the column and rows provided and what they actually mean to say through the numbers and text. This action gave me the idea of how to differentiate the casual and member(Annual member).
#
#
# -Few of the idea i got is to differential them through the time duration in
# riding the bike and type of bike used by them on daily basis.
# (Note:- This is just the idea i got after an overview of what to do, it may not come out to be exact true or same .. idea will change once we start analysing.)

# %% [markdown]
# ### ***Getting Ready for Analyzing***
#
#
# ---
#
#
#
# ---
#
#
#
# I have put the data in google drive under the data folder and then from their i can get the access of the csv files of all 3 months
#
# We are going to use google colab for analysing and data visualizatuion.This is easy to process the data of all 3 months as excel cant handle so much data.
#
# Before analyzing in python, i have added the column of days_pf_week in all the csv file using excel which inform us about the days of that month. for eg. 1=Monday and 7=Sunday and so on. Also i kept the format of that column as Number.

# %% [markdown]
# # **Analysis**
#
# I'll be using the jupyter in google colab
#
# Libraries used here are
#
#
# *   Pandas
# *   MatplotLib
# *   Numpy

# %% [markdown]
# ## Sept 2022 month Data Analysis

# %%
import pandas as pd

# %%
#getting csv file imported here from google drive

# %%
from google.colab import  drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path= '/content/drive/MyDrive/Data/202209-divvy-publictripdata.csv'

# %%
df= pd.read_csv(path)
df
# Out:
#                  ride_id  rideable_type        started_at          ended_at  \
# 0       5156990AC19CA285  electric_bike  01-09-2022 08:36  01-09-2022 08:39
# 1       E12D4A16BF51C274  electric_bike  01-09-2022 17:11  01-09-2022 17:14
# 2       A02B53CD7DB72DD7  electric_bike  01-09-2022 17:15  01-09-2022 17:16
# 3       C82E05FEE872DF11  electric_bike  01-09-2022 09:00  01-09-2022 09:10
# 4       4DEEB4550A266AE1  electric_bike  01-09-2022 07:30  01-09-2022 07:32
# ...                  ...            ...               ...               ...
# 701334  32ECA2B32C4B6F85   classic_bike  05-09-2022 17:59  05-09-2022 18:19
# 701335  14801F713026AEAE   classic_bike  30-09-2022 17:20  30-09-2022 17:34
# 701336  7CCAF5D6E88E45C0  electric_bike  04-09-2022 11:39  04-09-2022 11:50
# 701337  AF9A129D9AFAA40B  electric_bike  28-09-2022 13:42  28-09-2022 13:52
# 701338  60B56F4897429FCE  electric_bike  01-09-2022 20:07  01-09-2022 20:18
#
# ...

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at', 'ride_length',
#        'days_of_week', 'member_casual', 'start_station_name',
#        'start_station_id', 'end_station_name', 'end_station_id', 'start_lat',
#        'start_lng', 'end_lat', 'end_lng'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701339 entries, 0 to 701338
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             701339 non-null  object
#  1   rideable_type       701339 non-null  object
#  2   started_at          701339 non-null  object
#  3   ended_at            701339 non-null  object
#  4   ride_length         701339 non-null  object
#  5   days_of_week        701339 non-null  int64
#  6   member_casual       701339 non-null  object
#  7   start_station_name  597559 non-null  object
#  8   start_station_id    597559 non-null  object
#  9   end_station_name    590154 non-null  object
#  10  end_station_id      590154 non-null  object
#  11  start_lat           701339 non-null  float64
#  12  start_lng           701339 non-null  float64
#  13  end_lat             700627 non-null  float64
#  14  end_lng             700627 non-null  float64
# ...

# %% [markdown]
# Converting the started_at and ended_at column into datetime datatype for better future references and graphical representation

# %%
df['started_at'] = pd.to_datetime(df['started_at'],dayfirst=True)
df['ended_at'] = pd.to_datetime(df['ended_at'], dayfirst=True)
df
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       5156990AC19CA285  electric_bike 2022-09-01 08:36:00
# 1       E12D4A16BF51C274  electric_bike 2022-09-01 17:11:00
# 2       A02B53CD7DB72DD7  electric_bike 2022-09-01 17:15:00
# 3       C82E05FEE872DF11  electric_bike 2022-09-01 09:00:00
# 4       4DEEB4550A266AE1  electric_bike 2022-09-01 07:30:00
# ...                  ...            ...                 ...
# 701334  32ECA2B32C4B6F85   classic_bike 2022-09-05 17:59:00
# 701335  14801F713026AEAE   classic_bike 2022-09-30 17:20:00
# 701336  7CCAF5D6E88E45C0  electric_bike 2022-09-04 11:39:00
# 701337  AF9A129D9AFAA40B  electric_bike 2022-09-28 13:42:00
# 701338  60B56F4897429FCE  electric_bike 2022-09-01 20:07:00
#
#                   ended_at ride_length  days_of_week member_casual  \
# 0      2022-09-01 08:39:00    00:02:43             5        casual
# 1      2022-09-01 17:14:00    00:03:16             5        casual
# ...

# %% [markdown]
# Firstly, knowing the total casual and member uses the bikes of the company.

# %%
df['member_casual'].value_counts(ascending=True)
# Out:
# casual    296697
# member    404642
# Name: member_casual, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data_pie = df['member_casual'].value_counts().rename_axis('member_casual').reset_index(name='member_casual_count')

# %%
plt.figure(figsize=(5,5))
plt.pie(data_pie.member_casual_count, labels=data_pie.member_casual, startangle=90, autopct= '%.1f%%')
plt.title('Percentage of types of riders')
plt.show()

# %% [markdown]
# This above Pie chart explains that the casual are less compared to the Members
#
# **[Member > Casual]**

# %%
import seaborn as sns

# %%
dfg2= pd.crosstab(df.days_of_week,df.rideable_type, values= df.rideable_type , aggfunc = 'count')
dfg2
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# days_of_week
# 1                     32568         2924          36502
# 2                     35389         2462          40623
# 3                     38635         1702          46282
# 4                     41383         1968          51660
# 5                     51992         2429          68009
# 6                     53812         3381          71522
# 7                     52363         4960          60773

# %%
# %matplotlib inline
import numpy as np

# %%
dfg2.plot.line(ylim=(1000,100000),yticks=np.arange(10000,110000,10000))

# %% [markdown]
# ### ***dfssg2 graph***
#
# -The usage of docked bike is less compare to other bikes
#
# -On Sunday, there is sudden rise of demand in electric bike including other two as well

# %%
dfg3= pd.crosstab(df.member_casual,df.rideable_type, values= df.rideable_type , aggfunc = 'count')
dfg3
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# member_casual
# casual             105375.0      19826.0       171496.0
# member             200767.0          NaN       203875.0

# %%
dfg3.plot.bar(ylim=(10000,300000),yticks=np.arange(50000,300000,50000))

# %% [markdown]
# ### ***dfssg3 graph***
#
# -This graph shows that not a single 'member' has used the docked bike
#
# -Maybe from the station, member picked the bike - there is no availibilty of docked bike leading to not to use that bike.

# %%
dfg4= pd.crosstab(df.days_of_week, df.member_casual, values= df.rideable_type , aggfunc = 'count')
dfg4
# Out:
# member_casual  casual  member
# days_of_week
# 1               36254   35740
# 2               31052   47422
# 3               29586   57033
# 4               33504   61507
# 5               45839   76591
# 6               56385   72330
# 7               64077   54019

# %%
dfg4.plot.bar(ylim=(10000,100000),yticks=np.arange(10000,200000,10000))

# %% [markdown]
# ### ***dfssg4 graph***
#
# - We can see the increase of casual riders on Monday and Sunday compare to members
#
# - And during rest of the days there is decrease of casual riders compare to member
#
# - Member on Thursday, Friday, Saturday are in high quantity compare to other days

# %% [markdown]
# Total Rows

# %%
len(df)
# Out:
# 701339

# %% [markdown]
# Getting the difference of ended_at and started_at time to know the ride length of each rider

# %%
df['duration'] = df['ended_at'] - df['started_at']
df
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       5156990AC19CA285  electric_bike 2022-09-01 08:36:00
# 1       E12D4A16BF51C274  electric_bike 2022-09-01 17:11:00
# 2       A02B53CD7DB72DD7  electric_bike 2022-09-01 17:15:00
# 3       C82E05FEE872DF11  electric_bike 2022-09-01 09:00:00
# 4       4DEEB4550A266AE1  electric_bike 2022-09-01 07:30:00
# ...                  ...            ...                 ...
# 701334  32ECA2B32C4B6F85   classic_bike 2022-09-05 17:59:00
# 701335  14801F713026AEAE   classic_bike 2022-09-30 17:20:00
# 701336  7CCAF5D6E88E45C0  electric_bike 2022-09-04 11:39:00
# 701337  AF9A129D9AFAA40B  electric_bike 2022-09-28 13:42:00
# 701338  60B56F4897429FCE  electric_bike 2022-09-01 20:07:00
#
#                   ended_at ride_length  days_of_week member_casual  \
# 0      2022-09-01 08:39:00    00:02:43             5        casual
# 1      2022-09-01 17:14:00    00:03:16             5        casual
# ...

# %% [markdown]
# Adding the column of start_hours which will represent the hour of when the rider started riding the bike

# %%
df['start_hours']= df.started_at.dt.hour
df
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       5156990AC19CA285  electric_bike 2022-09-01 08:36:00
# 1       E12D4A16BF51C274  electric_bike 2022-09-01 17:11:00
# 2       A02B53CD7DB72DD7  electric_bike 2022-09-01 17:15:00
# 3       C82E05FEE872DF11  electric_bike 2022-09-01 09:00:00
# 4       4DEEB4550A266AE1  electric_bike 2022-09-01 07:30:00
# ...                  ...            ...                 ...
# 701334  32ECA2B32C4B6F85   classic_bike 2022-09-05 17:59:00
# 701335  14801F713026AEAE   classic_bike 2022-09-30 17:20:00
# 701336  7CCAF5D6E88E45C0  electric_bike 2022-09-04 11:39:00
# 701337  AF9A129D9AFAA40B  electric_bike 2022-09-28 13:42:00
# 701338  60B56F4897429FCE  electric_bike 2022-09-01 20:07:00
#
#                   ended_at ride_length  days_of_week member_casual  \
# 0      2022-09-01 08:39:00    00:02:43             5        casual
# 1      2022-09-01 17:14:00    00:03:16             5        casual
# ...

# %%
df['start_hours'].mean()
# Out:
# 14.210984987288601

# %%
df.start_hours.value_counts().sort_index().plot()

# %% [markdown]
# Plotting the graph which represent at what time most of the riders start riding the bike.
#
# ***Note:*** Its not the mean but count

# %% [markdown]
# Obtaining the duration's min to later plot the graph

# %%
df['duration_min']= df.duration.dt.total_seconds()/60
df
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       5156990AC19CA285  electric_bike 2022-09-01 08:36:00
# 1       E12D4A16BF51C274  electric_bike 2022-09-01 17:11:00
# 2       A02B53CD7DB72DD7  electric_bike 2022-09-01 17:15:00
# 3       C82E05FEE872DF11  electric_bike 2022-09-01 09:00:00
# 4       4DEEB4550A266AE1  electric_bike 2022-09-01 07:30:00
# ...                  ...            ...                 ...
# 701334  32ECA2B32C4B6F85   classic_bike 2022-09-05 17:59:00
# 701335  14801F713026AEAE   classic_bike 2022-09-30 17:20:00
# 701336  7CCAF5D6E88E45C0  electric_bike 2022-09-04 11:39:00
# 701337  AF9A129D9AFAA40B  electric_bike 2022-09-28 13:42:00
# 701338  60B56F4897429FCE  electric_bike 2022-09-01 20:07:00
#
#                   ended_at ride_length  days_of_week member_casual  \
# 0      2022-09-01 08:39:00    00:02:43             5        casual
# 1      2022-09-01 17:14:00    00:03:16             5        casual
# ...

# %%
dfg7= pd.crosstab(df.days_of_week, df.member_casual, values= df.start_hours , aggfunc = 'mean')
dfg7
# Out:
# member_casual     casual     member
# days_of_week
# 1              12.992966  13.524426
# 2              14.334922  14.180528
# 3              14.649598  13.950029
# 4              14.908280  14.148016
# 5              15.033661  14.190401
# 6              14.898093  14.196087
# 7              14.116001  13.859179

# %%
dfg7.plot.line()

# %% [markdown]
# ### ***dfssg7 graph***
#
# - This graph represent that at what time and which day, casual and member start riding.
#
# - we see that casual mostly start riding around 2.30-3 pm in the afternoon during most(Wed,thurs,fri) of the days.
#
# - we see that member mostly start riding around 1.30-2 pm in the afternoon almost all the days.

# %% [markdown]
# Mean of the duration _min

# %%
df.duration_min.mean()
# Out:
# 19.311046441164688

# %% [markdown]
# Implementing the code to get the mean of the duration_min of casual and members differently

# %%
data_ji= df.groupby('member_casual')['duration_min'].mean()

# %%
data_ji
# Out:
# member_casual
# casual    27.985376
# member    12.950739
# Name: duration_min, dtype: float64

# %%
data_ji.plot.bar()

# %% [markdown]
# Here, we can see the gap of the ride_length between the casual and member.
# - this iimplies that casual rides the bike double the member
#
# ## [ ~ Member = 2Casual ]

# %% [markdown]
# ## Top 5 start_station used by Casuals

# %%
dfg9 = df.groupby(['member_casual','start_station_name'])['start_station_name'].count()._get_value('casual').sort_values(ascending=False).head(5)
dfg9
# Out:
# start_station_name
# Streeter Dr & Grand Ave               7016
# DuSable Lake Shore Dr & Monroe St     3614
# Millennium Park                       3232
# Michigan Ave & Oak St                 3059
# DuSable Lake Shore Dr & North Blvd    2653
# Name: start_station_name, dtype: int64

# %%
dfg9.plot.bar()

# %% [markdown]
# ## Top 5 start_station used by Members

# %%
dfg10 = df.groupby(['member_casual','start_station_name'])['start_station_name'].count()._get_value('member').sort_values(ascending=False).head(5)
dfg10
# Out:
# start_station_name
# Loomis St & Lexington St    3150
# Kingsbury St & Kinzie St    2555
# Clark St & Elm St           2530
# Wells St & Concord Ln       2456
# Morgan St & Polk St         2400
# Name: start_station_name, dtype: int64

# %%
dfg10.plot.bar()

# %% [markdown]
# ## Top 5 end_station used by Casuals

# %%
dfg11 = df.groupby(['member_casual','end_station_name'])['end_station_name'].count()._get_value('casual').sort_values(ascending=False).head(5)
dfg11
# Out:
# end_station_name
# Streeter Dr & Grand Ave               7185
# Millennium Park                       3395
# DuSable Lake Shore Dr & Monroe St     3280
# Michigan Ave & Oak St                 3222
# DuSable Lake Shore Dr & North Blvd    2836
# Name: end_station_name, dtype: int64

# %%
dfg11.plot.bar()

# %% [markdown]
# ## Top 5 end_station used by Members

# %%
dfg12 = df.groupby(['member_casual','end_station_name'])['end_station_name'].count()._get_value('member').sort_values(ascending=False).head(5)
dfg12
# Out:
# end_station_name
# Loomis St & Lexington St    3248
# Clark St & Elm St           2561
# Wells St & Concord Ln       2502
# Kingsbury St & Kinzie St    2487
# Morgan St & Polk St         2452
# Name: end_station_name, dtype: int64

# %%
dfg12.plot.bar()

# %% [markdown]
# ## October 2022 data analyzing

# %% [markdown]
# *Similarly, working on other month data to obtain the analysis.*

# %%
path1 = '/content/drive/MyDrive/Data/202210-divvy-tripdata.csv'

# %%
df1 = pd.read_csv(path1)
df1
# Out:
#                  ride_id  rideable_type        started_at          ended_at  \
# 0       A50255C1E17942AB   classic_bike  14-10-2022 17:13  14-10-2022 17:19
# 1       DB692A70BD2DD4E3  electric_bike  01-10-2022 16:29  01-10-2022 16:49
# 2       3C02727AAF60F873  electric_bike  19-10-2022 18:55  19-10-2022 19:03
# 3       47E653FDC2D99236  electric_bike  31-10-2022 07:52  31-10-2022 07:58
# 4       8B5407BE535159BF   classic_bike  13-10-2022 18:41  13-10-2022 19:26
# ...                  ...            ...               ...               ...
# 558680  BC3BFA659C9AB6F1   classic_bike  30-10-2022 01:41  30-10-2022 01:57
# 558681  ACD65450291CF95F   classic_bike  30-10-2022 01:41  30-10-2022 01:57
# 558682  4AAC03D1438E97CA   classic_bike  15-10-2022 09:34  15-10-2022 10:03
# 558683  8E6F3F29785E5D40   classic_bike  09-10-2022 10:21  09-10-2022 10:43
# 558684  8D14CBE672431920    docked_bike  22-10-2022 13:17  22-10-2022 13:46
#
# ...

# %%
df1.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at', 'days_of_week',
#        'ride_length', 'member_casual', 'start_station_name',
#        'start_station_id', 'end_station_name', 'end_station_id', 'start_lat',
#        'start_lng', 'end_lat', 'end_lng'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558685 entries, 0 to 558684
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             558685 non-null  object
#  1   rideable_type       558685 non-null  object
#  2   started_at          558685 non-null  object
#  3   ended_at            558685 non-null  object
#  4   days_of_week        558685 non-null  int64
#  5   ride_length         558685 non-null  object
#  6   member_casual       558685 non-null  object
#  7   start_station_name  467330 non-null  object
#  8   start_station_id    467330 non-null  object
#  9   end_station_name    462068 non-null  object
#  10  end_station_id      462068 non-null  object
#  11  start_lat           558685 non-null  float64
#  12  start_lng           558685 non-null  float64
#  13  end_lat             558210 non-null  float64
#  14  end_lng             558210 non-null  float64
# ...

# %%
df1['member_casual'].value_counts(ascending=True)
# Out:
# casual    208989
# member    349696
# Name: member_casual, dtype: int64

# %%
data_pie1 = df1['member_casual'].value_counts().rename_axis('member_casual').reset_index(name='member_casual_count')

# %%
plt.figure(figsize=(5,5))
plt.pie(data_pie1.member_casual_count, labels=data_pie1.member_casual, startangle=90, autopct= '%.1f%%')
plt.title('Percentage of types of riders')
plt.show()

# %%
df1g2= pd.crosstab(df1.days_of_week,df1.rideable_type, values= df1.rideable_type , aggfunc = 'count')
df1g2
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# days_of_week
# 1                     36532         3023          55492
# 2                     34412         1648          49463
# 3                     21639          714          33089
# 4                     26902          973          41611
# 5                     26547         1167          44110
# 6                     25664         1677          43663
# 7                     41864         3412          65083

# %%
df1g2.plot.line(ylim=(0,70000),yticks=np.arange(0,80000,10000))

# %%
df1g3= pd.crosstab(df1.member_casual,df1.rideable_type, values= df1.rideable_type , aggfunc = 'count')
df1g3
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# member_casual
# casual              61568.0      12614.0       134807.0
# member             151992.0          NaN       197704.0

# %%
df1g3.plot.bar()

# %%
df1g4= pd.crosstab( df1.days_of_week, df1.member_casual,values= df1.rideable_type , aggfunc = 'count')
df1g4
# Out:
# member_casual  casual  member
# days_of_week
# 1               44681   50366
# 2               27234   58289
# 3               15694   39748
# 4               20593   48893
# 5               22585   49239
# 6               25980   45024
# 7               52222   58137

# %%
df1g4.plot.bar()

# %%
df1['started_at'] = pd.to_datetime(df1['started_at'], infer_datetime_format=True)
print(df1['started_at'].mean())
# Out:
# 2022-10-16 00:36:30.919892992

# %%
df1g6= pd.crosstab(df1.days_of_week, df1.member_casual)
df1g6
# Out:
# member_casual  casual  member
# days_of_week
# 1               44681   50366
# 2               27234   58289
# 3               15694   39748
# 4               20593   48893
# 5               22585   49239
# 6               25980   45024
# 7               52222   58137

# %%
df1g6.plot.bar()

# %%
df1['started_at'] = pd.to_datetime(df1['started_at'],dayfirst=True)
df1['ended_at'] = pd.to_datetime(df1['ended_at'], dayfirst=True)
df1
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A50255C1E17942AB   classic_bike 2022-10-14 17:13:00
# 1       DB692A70BD2DD4E3  electric_bike 2022-10-01 16:29:00
# 2       3C02727AAF60F873  electric_bike 2022-10-19 18:55:00
# 3       47E653FDC2D99236  electric_bike 2022-10-31 07:52:00
# 4       8B5407BE535159BF   classic_bike 2022-10-13 18:41:00
# ...                  ...            ...                 ...
# 558680  BC3BFA659C9AB6F1   classic_bike 2022-10-30 01:41:00
# 558681  ACD65450291CF95F   classic_bike 2022-10-30 01:41:00
# 558682  4AAC03D1438E97CA   classic_bike 2022-10-15 09:34:00
# 558683  8E6F3F29785E5D40   classic_bike 2022-10-09 10:21:00
# 558684  8D14CBE672431920    docked_bike 2022-10-22 13:17:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-10-14 17:19:00             6    00:06:09        member
# 1      2022-10-01 16:49:00             7    00:19:40        casual
# ...

# %%
 df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558685 entries, 0 to 558684
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             558685 non-null  object
#  1   rideable_type       558685 non-null  object
#  2   started_at          558685 non-null  datetime64[ns]
#  3   ended_at            558685 non-null  datetime64[ns]
#  4   days_of_week        558685 non-null  int64
#  5   ride_length         558685 non-null  object
#  6   member_casual       558685 non-null  object
#  7   start_station_name  467330 non-null  object
#  8   start_station_id    467330 non-null  object
#  9   end_station_name    462068 non-null  object
#  10  end_station_id      462068 non-null  object
#  11  start_lat           558685 non-null  float64
#  12  start_lng           558685 non-null  float64
#  13  end_lat             558210 non-null  float64
# ...

# %%
df1['duration'] = df1['ended_at'] - df1['started_at']
df1
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A50255C1E17942AB   classic_bike 2022-10-14 17:13:00
# 1       DB692A70BD2DD4E3  electric_bike 2022-10-01 16:29:00
# 2       3C02727AAF60F873  electric_bike 2022-10-19 18:55:00
# 3       47E653FDC2D99236  electric_bike 2022-10-31 07:52:00
# 4       8B5407BE535159BF   classic_bike 2022-10-13 18:41:00
# ...                  ...            ...                 ...
# 558680  BC3BFA659C9AB6F1   classic_bike 2022-10-30 01:41:00
# 558681  ACD65450291CF95F   classic_bike 2022-10-30 01:41:00
# 558682  4AAC03D1438E97CA   classic_bike 2022-10-15 09:34:00
# 558683  8E6F3F29785E5D40   classic_bike 2022-10-09 10:21:00
# 558684  8D14CBE672431920    docked_bike 2022-10-22 13:17:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-10-14 17:19:00             6    00:06:09        member
# 1      2022-10-01 16:49:00             7    00:19:40        casual
# ...

# %%
df1['start_hours']= df1.started_at.dt.hour
df1
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A50255C1E17942AB   classic_bike 2022-10-14 17:13:00
# 1       DB692A70BD2DD4E3  electric_bike 2022-10-01 16:29:00
# 2       3C02727AAF60F873  electric_bike 2022-10-19 18:55:00
# 3       47E653FDC2D99236  electric_bike 2022-10-31 07:52:00
# 4       8B5407BE535159BF   classic_bike 2022-10-13 18:41:00
# ...                  ...            ...                 ...
# 558680  BC3BFA659C9AB6F1   classic_bike 2022-10-30 01:41:00
# 558681  ACD65450291CF95F   classic_bike 2022-10-30 01:41:00
# 558682  4AAC03D1438E97CA   classic_bike 2022-10-15 09:34:00
# 558683  8E6F3F29785E5D40   classic_bike 2022-10-09 10:21:00
# 558684  8D14CBE672431920    docked_bike 2022-10-22 13:17:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-10-14 17:19:00             6    00:06:09        member
# 1      2022-10-01 16:49:00             7    00:19:40        casual
# ...

# %%
df1.start_hours.value_counts().sort_index().plot()

# %%
df1['duration_min']= df1.duration.dt.total_seconds()/60
df1
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A50255C1E17942AB   classic_bike 2022-10-14 17:13:00
# 1       DB692A70BD2DD4E3  electric_bike 2022-10-01 16:29:00
# 2       3C02727AAF60F873  electric_bike 2022-10-19 18:55:00
# 3       47E653FDC2D99236  electric_bike 2022-10-31 07:52:00
# 4       8B5407BE535159BF   classic_bike 2022-10-13 18:41:00
# ...                  ...            ...                 ...
# 558680  BC3BFA659C9AB6F1   classic_bike 2022-10-30 01:41:00
# 558681  ACD65450291CF95F   classic_bike 2022-10-30 01:41:00
# 558682  4AAC03D1438E97CA   classic_bike 2022-10-15 09:34:00
# 558683  8E6F3F29785E5D40   classic_bike 2022-10-09 10:21:00
# 558684  8D14CBE672431920    docked_bike 2022-10-22 13:17:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-10-14 17:19:00             6    00:06:09        member
# 1      2022-10-01 16:49:00             7    00:19:40        casual
# ...

# %%
df1g11= pd.crosstab(df1.days_of_week, df1.member_casual, values= df1.start_hours , aggfunc = 'mean')
df1g11
# Out:
# member_casual     casual     member
# days_of_week
# 1              12.666368  13.377119
# 2              14.403466  14.022200
# 3              13.599847  13.262881
# 4              14.863546  14.269302
# 5              14.596856  13.923089
# 6              14.894804  14.275164
# 7              14.005534  13.896658

# %%
df1g11.plot.line()

# %%
df1['end_hours']= df1.ended_at.dt.strftime('%H:%M')
df1
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       A50255C1E17942AB   classic_bike 2022-10-14 17:13:00
# 1       DB692A70BD2DD4E3  electric_bike 2022-10-01 16:29:00
# 2       3C02727AAF60F873  electric_bike 2022-10-19 18:55:00
# 3       47E653FDC2D99236  electric_bike 2022-10-31 07:52:00
# 4       8B5407BE535159BF   classic_bike 2022-10-13 18:41:00
# ...                  ...            ...                 ...
# 558680  BC3BFA659C9AB6F1   classic_bike 2022-10-30 01:41:00
# 558681  ACD65450291CF95F   classic_bike 2022-10-30 01:41:00
# 558682  4AAC03D1438E97CA   classic_bike 2022-10-15 09:34:00
# 558683  8E6F3F29785E5D40   classic_bike 2022-10-09 10:21:00
# 558684  8D14CBE672431920    docked_bike 2022-10-22 13:17:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-10-14 17:19:00             6    00:06:09        member
# 1      2022-10-01 16:49:00             7    00:19:40        casual
# ...

# %%
df1.end_hours.value_counts().plot()

# %%
df1.duration_min.mean()
# Out:
# 17.356499637541727

# %%
data_ji1= df1.groupby('member_casual')['duration_min'].mean()
data_ji1
# Out:
# member_casual
# casual    26.390131
# member    11.957726
# Name: duration_min, dtype: float64

# %%
data_ji1.plot.bar()

# %%
df1g9 = df1.groupby(['member_casual','start_station_name'])['start_station_name'].count()._get_value('casual').sort_values(ascending=False).head(5)
df1g9
# Out:
# start_station_name
# Streeter Dr & Grand Ave              4391
# DuSable Lake Shore Dr & Monroe St    2956
# Millennium Park                      2084
# Shedd Aquarium                       1931
# Michigan Ave & Oak St                1842
# Name: start_station_name, dtype: int64

# %%
df1g9.plot.bar()

# %%
df1g10 = df1.groupby(['member_casual','start_station_name'])['start_station_name'].count()._get_value('member').sort_values(ascending=False).head(5)
df1g10
# Out:
# start_station_name
# Ellis Ave & 60th St         3781
# University Ave & 57th St    3594
# Loomis St & Lexington St    2736
# Ellis Ave & 55th St         2601
# Clark St & Elm St           2346
# Name: start_station_name, dtype: int64

# %%
df1g10.plot.bar()

# %%
df1g11 = df1.groupby(['member_casual','end_station_name'])['end_station_name'].count()._get_value('casual').sort_values(ascending=False).head(5)
df1g11
# Out:
# end_station_name
# Streeter Dr & Grand Ave              4594
# DuSable Lake Shore Dr & Monroe St    2672
# Millennium Park                      2241
# Michigan Ave & Oak St                1902
# Shedd Aquarium                       1702
# Name: end_station_name, dtype: int64

# %%
df1g11.plot.bar()

# %%
df1g12 = df1.groupby(['member_casual','end_station_name'])['end_station_name'].count()._get_value('member').sort_values(ascending=False).head(5)
df1g12
# Out:
# end_station_name
# Ellis Ave & 60th St         3842
# University Ave & 57th St    3544
# Loomis St & Lexington St    2764
# Ellis Ave & 55th St         2636
# Clark St & Elm St           2319
# Name: end_station_name, dtype: int64

# %%
df1g12.plot.bar()

# %% [markdown]
# ## November 2022 data anaylze

# %% [markdown]
# ***Similarly, working on other month data to get analysis***

# %%
path2 = '/content/drive/MyDrive/Data/202211-divvy-tripdata.csv'

# %%
df2 = pd.read_csv(path2)
df2
# Out:
#                  ride_id  rideable_type        started_at          ended_at  \
# 0       BCC66FC6FAB27CC7  electric_bike  10-11-2022 06:21  10-11-2022 06:31
# 1       772AB67E902C180F   classic_bike  04-11-2022 07:31  04-11-2022 07:46
# 2       585EAD07FDEC0152   classic_bike  21-11-2022 17:20  21-11-2022 17:34
# 3       91C4E7ED3C262FF9   classic_bike  25-11-2022 17:29  25-11-2022 17:45
# 4       709206A3104CABC8   classic_bike  29-11-2022 17:24  29-11-2022 17:42
# ...                  ...            ...               ...               ...
# 337730  C349E243A9BAA6F7  electric_bike  25-11-2022 11:19  25-11-2022 11:31
# 337731  B0B4E85DA43A9194   classic_bike  22-11-2022 16:57  22-11-2022 17:31
# 337732  8D148DD47B59530B   classic_bike  06-11-2022 13:04  06-11-2022 13:13
# 337733  0D1170BA18FD33D1   classic_bike  06-11-2022 09:41  06-11-2022 15:17
# 337734  09B20DC75B5EA1E0  electric_bike  26-11-2022 11:59  26-11-2022 12:31
#
# ...

# %%
df2.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at', 'days_of_week',
#        'ride_length', 'member_casual', 'start_station_name',
#        'start_station_id', 'end_station_name', 'end_station_id', 'start_lat',
#        'start_lng', 'end_lat', 'end_lng'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337735 entries, 0 to 337734
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             337735 non-null  object
#  1   rideable_type       337735 non-null  object
#  2   started_at          337735 non-null  object
#  3   ended_at            337735 non-null  object
#  4   days_of_week        337735 non-null  int64
#  5   ride_length         337735 non-null  object
#  6   member_casual       337735 non-null  object
#  7   start_station_name  285778 non-null  object
#  8   start_station_id    285778 non-null  object
#  9   end_station_name    283476 non-null  object
#  10  end_station_id      283476 non-null  object
#  11  start_lat           337735 non-null  float64
#  12  start_lng           337735 non-null  float64
#  13  end_lat             337505 non-null  float64
#  14  end_lng             337505 non-null  float64
# ...

# %%
df2['started_at'] = pd.to_datetime(df2['started_at'],dayfirst=True)
df2['ended_at'] = pd.to_datetime(df2['ended_at'], dayfirst=True)
df2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       BCC66FC6FAB27CC7  electric_bike 2022-11-10 06:21:00
# 1       772AB67E902C180F   classic_bike 2022-11-04 07:31:00
# 2       585EAD07FDEC0152   classic_bike 2022-11-21 17:20:00
# 3       91C4E7ED3C262FF9   classic_bike 2022-11-25 17:29:00
# 4       709206A3104CABC8   classic_bike 2022-11-29 17:24:00
# ...                  ...            ...                 ...
# 337730  C349E243A9BAA6F7  electric_bike 2022-11-25 11:19:00
# 337731  B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:00
# 337732  8D148DD47B59530B   classic_bike 2022-11-06 13:04:00
# 337733  0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:00
# 337734  09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-11-10 06:31:00             5    00:09:32        member
# 1      2022-11-04 07:46:00             6    00:14:30        member
# ...

# %%
df2['member_casual'].value_counts(ascending=True)
# Out:
# casual    100772
# member    236963
# Name: member_casual, dtype: int64

# %%
data_pie2 = df2['member_casual'].value_counts().rename_axis('member_casual').reset_index(name='member_casual_count')

# %%
plt.figure(figsize=(5,5))
plt.pie(data_pie2.member_casual_count, labels=data_pie2.member_casual, startangle=90, autopct= '%.1f%%')
plt.title('Percentage of types of riders')
plt.show()

# %%
df2g2= pd.crosstab(df2.days_of_week,df2.rideable_type, values= df2.rideable_type , aggfunc = 'count')
df2g2
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# days_of_week
# 1                     14645          912          18147
# 2                     18755          512          23338
# 3                     26115          768          35039
# 4                     27509          860          36858
# 5                     25438         1085          30583
# 6                     19145          929          24788
# 7                     12994          820          18495

# %%
df2g2.plot.line(ylim=(0,40000),yticks=np.arange(0,50000,5000))

# %%
df2g3= pd.crosstab(df2.member_casual,df2.rideable_type, values= df2.rideable_type , aggfunc = 'count')
df2g3
# Out:
# rideable_type  classic_bike  docked_bike  electric_bike
# member_casual
# casual              33052.0       5886.0        61834.0
# member             111549.0          NaN       125414.0

# %%
df2g3.plot.bar()

# %%
df2g4= pd.crosstab( df2.days_of_week, df2.member_casual,values= df2.rideable_type , aggfunc = 'count')
df2g4
# Out:
# member_casual  casual  member
# days_of_week
# 1               12497   21207
# 2               10300   32305
# 3               15808   46114
# 4               17779   47448
# 5               17981   39125
# 6               14538   30324
# 7               11869   20440

# %%
df2g4.plot.bar()

# %%
df2['started_at'] = pd.to_datetime(df2['started_at'], infer_datetime_format=True)
print(df2['started_at'].mean())
# Out:
# 2022-11-13 05:58:08.833849600

# %%
df2g6= pd.crosstab(df2.days_of_week, df2.member_casual)
df2g6
# Out:
# member_casual  casual  member
# days_of_week
# 1               12497   21207
# 2               10300   32305
# 3               15808   46114
# 4               17779   47448
# 5               17981   39125
# 6               14538   30324
# 7               11869   20440

# %%
df2g6.plot.bar()

# %%
df2['started_at'] = pd.to_datetime(df2['started_at'])
df2['ended_at'] = pd.to_datetime(df2['ended_at'])
df2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       BCC66FC6FAB27CC7  electric_bike 2022-11-10 06:21:00
# 1       772AB67E902C180F   classic_bike 2022-11-04 07:31:00
# 2       585EAD07FDEC0152   classic_bike 2022-11-21 17:20:00
# 3       91C4E7ED3C262FF9   classic_bike 2022-11-25 17:29:00
# 4       709206A3104CABC8   classic_bike 2022-11-29 17:24:00
# ...                  ...            ...                 ...
# 337730  C349E243A9BAA6F7  electric_bike 2022-11-25 11:19:00
# 337731  B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:00
# 337732  8D148DD47B59530B   classic_bike 2022-11-06 13:04:00
# 337733  0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:00
# 337734  09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-11-10 06:31:00             5    00:09:32        member
# 1      2022-11-04 07:46:00             6    00:14:30        member
# ...

# %%
 df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337735 entries, 0 to 337734
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             337735 non-null  object
#  1   rideable_type       337735 non-null  object
#  2   started_at          337735 non-null  datetime64[ns]
#  3   ended_at            337735 non-null  datetime64[ns]
#  4   days_of_week        337735 non-null  int64
#  5   ride_length         337735 non-null  object
#  6   member_casual       337735 non-null  object
#  7   start_station_name  285778 non-null  object
#  8   start_station_id    285778 non-null  object
#  9   end_station_name    283476 non-null  object
#  10  end_station_id      283476 non-null  object
#  11  start_lat           337735 non-null  float64
#  12  start_lng           337735 non-null  float64
#  13  end_lat             337505 non-null  float64
# ...

# %%
df2['duration'] = df2['ended_at'] - df2['started_at']
df2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       BCC66FC6FAB27CC7  electric_bike 2022-11-10 06:21:00
# 1       772AB67E902C180F   classic_bike 2022-11-04 07:31:00
# 2       585EAD07FDEC0152   classic_bike 2022-11-21 17:20:00
# 3       91C4E7ED3C262FF9   classic_bike 2022-11-25 17:29:00
# 4       709206A3104CABC8   classic_bike 2022-11-29 17:24:00
# ...                  ...            ...                 ...
# 337730  C349E243A9BAA6F7  electric_bike 2022-11-25 11:19:00
# 337731  B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:00
# 337732  8D148DD47B59530B   classic_bike 2022-11-06 13:04:00
# 337733  0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:00
# 337734  09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-11-10 06:31:00             5    00:09:32        member
# 1      2022-11-04 07:46:00             6    00:14:30        member
# ...

# %%
df2['start_hours']= df2.started_at.dt.hour
df2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       BCC66FC6FAB27CC7  electric_bike 2022-11-10 06:21:00
# 1       772AB67E902C180F   classic_bike 2022-11-04 07:31:00
# 2       585EAD07FDEC0152   classic_bike 2022-11-21 17:20:00
# 3       91C4E7ED3C262FF9   classic_bike 2022-11-25 17:29:00
# 4       709206A3104CABC8   classic_bike 2022-11-29 17:24:00
# ...                  ...            ...                 ...
# 337730  C349E243A9BAA6F7  electric_bike 2022-11-25 11:19:00
# 337731  B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:00
# 337732  8D148DD47B59530B   classic_bike 2022-11-06 13:04:00
# 337733  0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:00
# 337734  09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-11-10 06:31:00             5    00:09:32        member
# 1      2022-11-04 07:46:00             6    00:14:30        member
# ...

# %%
df2.start_hours.value_counts().sort_index().plot()

# %%
df2['duration_min']= df2.duration.dt.total_seconds()/60
df2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       BCC66FC6FAB27CC7  electric_bike 2022-11-10 06:21:00
# 1       772AB67E902C180F   classic_bike 2022-11-04 07:31:00
# 2       585EAD07FDEC0152   classic_bike 2022-11-21 17:20:00
# 3       91C4E7ED3C262FF9   classic_bike 2022-11-25 17:29:00
# 4       709206A3104CABC8   classic_bike 2022-11-29 17:24:00
# ...                  ...            ...                 ...
# 337730  C349E243A9BAA6F7  electric_bike 2022-11-25 11:19:00
# 337731  B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:00
# 337732  8D148DD47B59530B   classic_bike 2022-11-06 13:04:00
# 337733  0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:00
# 337734  09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-11-10 06:31:00             5    00:09:32        member
# 1      2022-11-04 07:46:00             6    00:14:30        member
# ...

# %%
df2g11= pd.crosstab(df2.days_of_week, df2.member_casual, values= df2.start_hours , aggfunc = 'mean')
df2g11
# Out:
# member_casual     casual     member
# days_of_week
# 1              12.922061  13.497524
# 2              13.962330  13.694722
# 3              14.253543  13.728456
# 4              14.544519  13.784944
# 5              14.353762  13.811962
# 6              14.102559  13.765005
# 7              13.510742  13.526957

# %%
df2g11.plot.line()

# %%
df2['end_hours']= df2.ended_at.dt.strftime('%H:%M')
df2
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       BCC66FC6FAB27CC7  electric_bike 2022-11-10 06:21:00
# 1       772AB67E902C180F   classic_bike 2022-11-04 07:31:00
# 2       585EAD07FDEC0152   classic_bike 2022-11-21 17:20:00
# 3       91C4E7ED3C262FF9   classic_bike 2022-11-25 17:29:00
# 4       709206A3104CABC8   classic_bike 2022-11-29 17:24:00
# ...                  ...            ...                 ...
# 337730  C349E243A9BAA6F7  electric_bike 2022-11-25 11:19:00
# 337731  B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:00
# 337732  8D148DD47B59530B   classic_bike 2022-11-06 13:04:00
# 337733  0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:00
# 337734  09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:00
#
#                   ended_at  days_of_week ride_length member_casual  \
# 0      2022-11-10 06:31:00             5    00:09:32        member
# 1      2022-11-04 07:46:00             6    00:14:30        member
# ...

# %%
df2.end_hours.value_counts().plot()

# %%
df2.duration_min.mean()
# Out:
# 14.160809510414971

# %%
data_ji2= df2.groupby('member_casual')['duration_min'].mean()
data_ji2
# Out:
# member_casual
# casual    21.287778
# member    11.129961
# Name: duration_min, dtype: float64

# %%
data_ji2.plot.bar()

# %%
df2g9 = df2.groupby(['member_casual','start_station_name'])['start_station_name'].count()._get_value('casual').sort_values(ascending=False).head(5)
df2g9
# Out:
# start_station_name
# Streeter Dr & Grand Ave              1732
# DuSable Lake Shore Dr & Monroe St    1165
# Millennium Park                       907
# Shedd Aquarium                        897
# Michigan Ave & Oak St                 604
# Name: start_station_name, dtype: int64

# %%
df2g9.plot.bar()

# %%
df2g10 = df2.groupby(['member_casual','start_station_name'])['start_station_name'].count()._get_value('member').sort_values(ascending=False).head(5)
df2g10
# Out:
# start_station_name
# Ellis Ave & 60th St             2314
# University Ave & 57th St        2266
# Kingsbury St & Kinzie St        1804
# Ellis Ave & 55th St             1714
# Clinton St & Washington Blvd    1655
# Name: start_station_name, dtype: int64

# %%
df2g10.plot.bar()

# %%
df2g11 = df2.groupby(['member_casual','end_station_name'])['end_station_name'].count()._get_value('casual').sort_values(ascending=False).head(5)
df2g11
# Out:
# end_station_name
# Streeter Dr & Grand Ave              1954
# Millennium Park                      1065
# DuSable Lake Shore Dr & Monroe St     995
# Shedd Aquarium                        799
# Michigan Ave & Oak St                 701
# Name: end_station_name, dtype: int64

# %%
df2g11.plot.bar()

# %%
df2g12 = df2.groupby(['member_casual','end_station_name'])['end_station_name'].count()._get_value('member').sort_values(ascending=False).head(5)
df2g12
# Out:
# end_station_name
# Ellis Ave & 60th St             2312
# University Ave & 57th St        2252
# Kingsbury St & Kinzie St        1842
# Clinton St & Washington Blvd    1776
# Ellis Ave & 55th St             1749
# Name: end_station_name, dtype: int64

# %%
df2g12.plot.bar()

# %% [markdown]
# # **For Conclusion and Recommendation view 1 year data analysis**
